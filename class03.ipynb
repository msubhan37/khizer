# %%
age = int(input("enter your age "))

# %%
if age >=18:
    print("you are eligible for vote")
elif age < 18 and age > 0:
    print("you are not eligible for vote")
# Out:
# you are not eligible for vote

# %%
num = int(input())
if num % 2==0:
    print(f"{ num } is an even")
else:
    print(f"{num} is an odd")
# Out:
# 156 is an even

# %% [markdown]
# if nasted

# %%
age=20
has_id=False

if age>=18:
    if has_id:
        print("you are allowed")

# %%
username="subhan"
password="1,2,3,4"
if username=="subhan":
    if password=="1,2,3,4":
      print("login successful")
# Out:
# login successfu

# %%
shop_open=True
basmati_rise=True

# %%
if shop_open:
    print("shop is open, you can go and buy rice")
    if basmati_rise:
        print("buy 1kg")
    else:
        print("there is no rice")
else:
    print("shop is close")
# Out:
# shop is open, you can go and buy rice
# buy 1kg

# %%
if shop_open:
    print("shop is open, you can go and buy rice")
    basmati_rice=bool(input("check for rice"))
    if basmati_rise=="True":
        print("buy 1kg")
    else:
        print("there is no rice")
else:
    print("shop is close")
# Out:
# shop is open, you can go and buy rice
# there is no rice

# %% [markdown]
# #COMMON COMPARISON OPRETORS

# %%
== EQULATE  5==5 True
!= NOT EQUAL TO 5!=3 True
> RREATER THAN 10>5 True
< LESS THAN 3<7 True
>= GREATAR THAN EQUAL TO 5>=5 True
<= LESS THAN EQUAL TO 4<=6 True

# %%
5==5
# Out:
# True

# %%
5>=5
# Out:
# True

# %%
6<=6
# Out:
# True

# %%
6<=4
# Out:
# False

# %%
num = 5!=3
print(num)
# Out:
# True

# %% [markdown]
# for loop

# %%
# list
for temp in [1,2,3,4,5]:
    print(temp)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#tuples
for temp in ("subhan","zahid",17,17.6,True):
    print(temp)
# Out:
# subhan
# zahid
# 17
# 17.6
# True

# %%
for i in range (6):
   print("subhan")
# Out:
# subhan
# subhan
# subhan
# subhan
# subhan
# subhan

# %%
age = int(input("enter your age"))

if age>17:
    print("you can vote")
else:
    print("you cant vote")
# Out:
# you cant vote

# %%
#set
for temp in {1,2,3,4,5,'a','b','c'}:
   print(temp)
